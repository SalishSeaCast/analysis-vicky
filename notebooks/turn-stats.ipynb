# %% [markdown]
# ## turn stats

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import netCDF4 as nc
import seaborn as sns
import matplotlib.colors as mcolors
import glob
import os
import xarray as xr
import datetime
from salishsea_tools import viz_tools, tidetools, geo_tools, gsw_calls
import pickle

# %matplotlib inline

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>

<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
pickle_in1 = open("/home/abhudia/Desktop/Wind speed/3points/winds_turn2015.pickle","rb")
pickle_in2 = open("/home/abhudia/Desktop/Wind speed/3points/winds_turn2016.pickle","rb")
pickle_in3 = open("/home/abhudia/Desktop/Wind speed/3points/winds_turn2017.pickle","rb")
pickle_in4 = open("/home/abhudia/Desktop/Wind speed/3points/winds_turn2018.pickle","rb")
example1 = pickle.load(pickle_in1)
example2 = pickle.load(pickle_in2)
example3 = pickle.load(pickle_in3)
example4 = pickle.load(pickle_in4)

# %%
two = np.append(example1, example2)

# %%
three = np.append(two, example3)
full = np.append(three, example4)

# %%
wnd_avg = np.array([])
wnd_min = np.array([])
wnd_max = np.array([])
wnd_std = np.array([])

for i in range(1450):
    start = 24*i
    end = start + 168
    wnd_avg = np.append(wnd_avg, full[start:end].mean())
    wnd_min = np.append(wnd_min, full[start:end].min())
    wnd_max = np.append(wnd_max, full[start:end].max())
    wnd_std = np.append(wnd_std, full[start:end].std())

# %%
pickle_in1 = open("/home/abhudia/Desktop/current speed/hourly/mag2015.pickle","rb")
pickle_in2 = open("/home/abhudia/Desktop/current speed/hourly/mag2016.pickle","rb")
pickle_in3 = open("/home/abhudia/Desktop/current speed/hourly/mag2017.pickle","rb")
pickle_in4 = open("/home/abhudia/Desktop/current speed/hourly/mag2018.pickle","rb")
example1 = pickle.load(pickle_in1)
example2 = pickle.load(pickle_in2)
example3 = pickle.load(pickle_in3)
example4 = pickle.load(pickle_in4)

# %%
two = np.append(example1[:,143,240], example2[:,143,240])
three = np.append(two, example3[:,143,240])
fullc = np.append(three, example4[:,143,240])
fullc.shape
# Out:
# (35064,)

# %%
cur_avg = np.array([])
cur_min = np.array([])
cur_max = np.array([])
cur_std = np.array([])

for i in range(1450):
    start = 24*i
    end = start + 168
    cur_avg = np.append(cur_avg, fullc[start:end].mean())
    cur_min = np.append(cur_min, fullc[start:end].min())
    cur_max = np.append(cur_max, fullc[start:end].max())
    cur_std = np.append(cur_std, fullc[start:end].std())

# %%
pickle_in1 = open("/home/abhudia/Desktop/salinity/3points/turn2015.pickle","rb")
pickle_in2 = open("/home/abhudia/Desktop/salinity/3points/turn2016.pickle","rb")
pickle_in3 = open("/home/abhudia/Desktop/salinity/3points/turn2017.pickle","rb")
pickle_in4 = open("/home/abhudia/Desktop/salinity/3points/turn2018.pickle","rb")
example1 = pickle.load(pickle_in1)
example2 = pickle.load(pickle_in2)
example3 = pickle.load(pickle_in3)
example4 = pickle.load(pickle_in4)

two = np.append(example1, example2)
three = np.append(two, example3)
fulls = np.append(three, example4)

# %%
sal_avg = np.array([])
sal_min = np.array([])
sal_max = np.array([])
sal_std = np.array([])

for i in range(1450):
    start = 24*i
    end = start + 168
    sal_avg = np.append(sal_avg, fulls[start:end].mean())
    sal_min = np.append(sal_min, fulls[start:end].min())
    sal_max = np.append(sal_max, fulls[start:end].max())
    sal_std = np.append(sal_std, fulls[start:end].std())

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

dates = np.array([datetime.date(2015,1,1) + datetime.timedelta(i) for i in range(1450)])
dates.shape
# Out:
# (1450,)

# %%
fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates,sal_avg)
ax[0].set_title('sal')
ax[1].plot(dates,cur_avg)
ax[1].set_title('cur')
ax[2].plot(dates,wnd_avg)
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on')
    ax.set_xlim(dates[0], dates[-1]);

# %%
#looking for days with high sal, wnd, and cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg > 28) & (cur_avg > 1.3) & (wnd_avg > 7)],
           sal_avg[(sal_avg > 28) & (cur_avg > 1.3) & (wnd_avg > 7)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg > 28) & (cur_avg > 1.3) & (wnd_avg > 7)],
           cur_avg[(sal_avg > 28) & (cur_avg > 1.3) & (wnd_avg > 7)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg > 28) & (cur_avg > 1.3) & (wnd_avg > 7)],
           wnd_avg[(sal_avg > 28) & (cur_avg > 1.3) & (wnd_avg > 7)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg > 28) & (cur_avg > 1.3) & (wnd_avg > 7)].shape)
# Out:
# (38,)

# %%
#looking for days with high sal, wnd, and low cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg > 25) & (cur_avg < 1) & (wnd_avg > 7)],
           sal_avg[(sal_avg > 25) & (cur_avg < 1) & (wnd_avg > 7)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg > 25) & (cur_avg < 1) & (wnd_avg > 7)],
           cur_avg[(sal_avg > 25) & (cur_avg < 1) & (wnd_avg > 7)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg > 25) & (cur_avg < 1) & (wnd_avg > 7)],
           wnd_avg[(sal_avg > 25) & (cur_avg < 1) & (wnd_avg > 7)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg > 25) & (cur_avg < 1) & (wnd_avg > 7)].shape)
# Out:
# (10,)

# %%
#looking for days with high sal, low wnd, and low cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg > 28) & (cur_avg < 1) & (wnd_avg < 4)],
           sal_avg[(sal_avg > 28) & (cur_avg < 1) & (wnd_avg < 4)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg > 28) & (cur_avg < 1) & (wnd_avg < 4)],
           cur_avg[(sal_avg > 28) & (cur_avg < 1) & (wnd_avg < 4)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg > 28) & (cur_avg < 1) & (wnd_avg < 4)],
           wnd_avg[(sal_avg > 28) & (cur_avg < 1) & (wnd_avg < 4)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg > 28) & (cur_avg < 1) & (wnd_avg < 4)].shape)
# Out:
# (79,)

# %%
#looking for days with low sal, low wnd, and low cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg < 27) & (cur_avg < 1) & (wnd_avg < 4)],
           sal_avg[(sal_avg < 27) & (cur_avg < 1) & (wnd_avg < 4)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg < 27) & (cur_avg < 1) & (wnd_avg < 4)],
           cur_avg[(sal_avg < 27) & (cur_avg < 1) & (wnd_avg < 4)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg < 27) & (cur_avg < 1) & (wnd_avg < 4)],
           wnd_avg[(sal_avg < 27) & (cur_avg < 1) & (wnd_avg < 4)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg < 27) & (cur_avg < 1) & (wnd_avg < 4)].shape)
# Out:
# (35,)

# %%
#looking for days with low sal, low wnd, and lhigh cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg < 4)],
           sal_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg < 4)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg < 4)],
           cur_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg < 4)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg < 4)],
           wnd_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg < 4)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg < 4)].shape)
# Out:
# (37,)

# %%
#looking for days with low sal, high wnd, and high cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg > 4)],
           sal_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg > 4)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg > 4)],
           cur_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg > 4)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg > 4)],
           wnd_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg > 4)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg < 28) & (cur_avg > 1.3) & (wnd_avg > 4)].shape)
# Out:
# (3,)

# %%
#looking for days with low sal, high wnd, and low cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg < 28) & (cur_avg < 1.3) & (wnd_avg > 4)],
           sal_avg[(sal_avg < 28) & (cur_avg < 1.3) & (wnd_avg > 4)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg < 28) & (cur_avg < 1.3) & (wnd_avg > 4)],
           cur_avg[(sal_avg < 28) & (cur_avg < 1.3) & (wnd_avg > 4)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg < 28) & (cur_avg < 1.3) & (wnd_avg > 4)],
           wnd_avg[(sal_avg < 28) & (cur_avg < 1.3) & (wnd_avg > 4)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg < 28) & (cur_avg < 1.3) & (wnd_avg > 4)].shape)
# Out:
# (11,)

# %%
#looking for days with high sal, low wnd, and high cur

fig, ax = plt.subplots(3,1, figsize = (15,10))
ax[0].plot(dates[(sal_avg > 29) & (cur_avg > 1.4) & (wnd_avg < 3.5)],
           sal_avg[(sal_avg > 29) & (cur_avg > 1.4) & (wnd_avg < 3.5)], 'o')
ax[0].set_title('sal')
ax[1].plot(dates[(sal_avg > 29) & (cur_avg > 1.4) & (wnd_avg < 3.5)],
           cur_avg[(sal_avg > 29) & (cur_avg > 1.4) & (wnd_avg < 3.5)], 'o')
ax[1].set_title('cur')
ax[2].plot(dates[(sal_avg > 29) & (cur_avg > 1.4) & (wnd_avg < 3.5)],
           wnd_avg[(sal_avg > 29) & (cur_avg > 1.4) & (wnd_avg < 3.5)], 'o')
ax[2].set_title('wnd')
for ax in ax:
    ax.grid('on');
print(wnd_avg[(sal_avg > 29) & (cur_avg > 1.4) & (wnd_avg < 3.5)].shape)
# Out:
# (28,)

# %% [markdown]
# ### Correlation between wind speed and surface current speed

# %%
np.correlate(full, fullc)
# Out:
# array([181341.07117872])

# %% [markdown]
# ### Correlation between wind speed and surface salinity

# %%
np.correlate(full, fulls)
# Out:
# array([4429118.63138574])

# %% [markdown]
# ### Correlation between curface salinity and surface current speed

# %%
np.correlate(fulls, fullc)
# Out:
# array([1225077.1], dtype=float32)
