# %% [markdown]
# # Checkers & Chess
# # May 26, 2017

# %%
import numpy as np
import netCDF4 as nc
import xarray as xr
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
VAT20 = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/VAT20/SalishSea_1h_20150507_20150514_grid_T_20150513-20150513.nc')
VAT21 = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/VAT21/SalishSea_1h_20150507_20150514_grid_T_20150513-20150513.nc')
VAT24 = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/VAT24/SalishSea_1h_20150507_20150514_grid_T_20150513-20150513.nc')
VAT25 = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/VAT25/SalishSea_1h_20150507_20150509_grid_T_20150508-20150508.nc')
VAT24b = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/VAT24/SalishSea_1h_20150507_20150514_grid_T_20150508-20150508.nc')

# %% [markdown]
# # VAT20 vs VAT21

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,8))
VAT20.sossheig.isel(time_counter=23).plot(ax=ax1)
VAT21.sossheig.isel(time_counter=23).plot(ax=ax2)

# %%
(VAT21.sossheig.isel(time_counter=23) - VAT20.sossheig.isel(time_counter=23)).plot(figsize=(10,8))

# %% [markdown]
# # VAT20 vs VAT24

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,8))
VAT20.sossheig.isel(time_counter=23).plot(ax=ax1)
VAT24.sossheig.isel(time_counter=23).plot(ax=ax2)

# %%
(VAT24.sossheig.isel(time_counter=23) - VAT20.sossheig.isel(time_counter=23)).plot(figsize=(10,8))

# %% [markdown]
# # VAT24 vs VAT25

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,8))
VAT24b.sossheig.isel(time_counter=23).plot(ax=ax1)
VAT25.sossheig.isel(time_counter=23).plot(ax=ax2)

# %%
(VAT24b.sossheig.isel(time_counter=23) - VAT25.sossheig.isel(time_counter=23)).plot(figsize=(10,8))
