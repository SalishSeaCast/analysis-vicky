# %% [markdown]
# ## Tidal Heights in Nov-Dec, 2014
# ### May 5, 2017

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nov01 = xr.open_dataset('/results/SalishSea/hindcast/01nov14/PointAtkinson.nc')
nov02 = xr.open_dataset('/results/SalishSea/hindcast/02nov14/PointAtkinson.nc')
nov03 = xr.open_dataset('/results/SalishSea/hindcast/03nov14/PointAtkinson.nc')
nov04 = xr.open_dataset('/results/SalishSea/hindcast/04nov14/PointAtkinson.nc')
nov05 = xr.open_dataset('/results/SalishSea/hindcast/05nov14/PointAtkinson.nc')
nov06 = xr.open_dataset('/results/SalishSea/hindcast/06nov14/PointAtkinson.nc')
nov07 = xr.open_dataset('/results/SalishSea/hindcast/07nov14/PointAtkinson.nc')
nov08 = xr.open_dataset('/results/SalishSea/hindcast/08nov14/PointAtkinson.nc')
nov09 = xr.open_dataset('/results/SalishSea/hindcast/09nov14/PointAtkinson.nc')
nov10 = xr.open_dataset('/results/SalishSea/hindcast/10nov14/PointAtkinson.nc')
nov11 = xr.open_dataset('/results/SalishSea/hindcast/11nov14/PointAtkinson.nc')
nov12 = xr.open_dataset('/results/SalishSea/hindcast/12nov14/PointAtkinson.nc')
nov13 = xr.open_dataset('/results/SalishSea/hindcast/13nov14/PointAtkinson.nc')
nov14 = xr.open_dataset('/results/SalishSea/hindcast/14nov14/PointAtkinson.nc')
nov15 = xr.open_dataset('/results/SalishSea/hindcast/15nov14/PointAtkinson.nc')
nov16 = xr.open_dataset('/results/SalishSea/hindcast/16nov14/PointAtkinson.nc')
nov17 = xr.open_dataset('/results/SalishSea/hindcast/17nov14/PointAtkinson.nc')
nov18 = xr.open_dataset('/results/SalishSea/hindcast/18nov14/PointAtkinson.nc')
nov19 = xr.open_dataset('/results/SalishSea/hindcast/19nov14/PointAtkinson.nc')
nov20 = xr.open_dataset('/results/SalishSea/hindcast/20nov14/PointAtkinson.nc')
nov21 = xr.open_dataset('/results/SalishSea/hindcast/21nov14/PointAtkinson.nc')
nov22 = xr.open_dataset('/results/SalishSea/hindcast/22nov14/PointAtkinson.nc')
nov23 = xr.open_dataset('/results/SalishSea/hindcast/23nov14/PointAtkinson.nc')
nov24 = xr.open_dataset('/results/SalishSea/hindcast/24nov14/PointAtkinson.nc')
nov25 = xr.open_dataset('/results/SalishSea/hindcast/25nov14/PointAtkinson.nc')
nov26 = xr.open_dataset('/results/SalishSea/hindcast/26nov14/PointAtkinson.nc')
nov27 = xr.open_dataset('/results/SalishSea/hindcast/27nov14/PointAtkinson.nc')
nov28 = xr.open_dataset('/results/SalishSea/hindcast/28nov14/PointAtkinson.nc')
nov29 = xr.open_dataset('/results/SalishSea/hindcast/29nov14/PointAtkinson.nc')
nov30 = xr.open_dataset('/results/SalishSea/hindcast/30nov14/PointAtkinson.nc')

# %%
dec01 = xr.open_dataset('/results/SalishSea/hindcast/01dec14/PointAtkinson.nc')
dec02 = xr.open_dataset('/results/SalishSea/hindcast/02dec14/PointAtkinson.nc')
dec03 = xr.open_dataset('/results/SalishSea/hindcast/03dec14/PointAtkinson.nc')
dec04 = xr.open_dataset('/results/SalishSea/hindcast/04dec14/PointAtkinson.nc')
dec05 = xr.open_dataset('/results/SalishSea/hindcast/05dec14/PointAtkinson.nc')
dec06 = xr.open_dataset('/results/SalishSea/hindcast/06dec14/PointAtkinson.nc')
dec07 = xr.open_dataset('/results/SalishSea/hindcast/07dec14/PointAtkinson.nc')
dec08 = xr.open_dataset('/results/SalishSea/hindcast/08dec14/PointAtkinson.nc')
dec09 = xr.open_dataset('/results/SalishSea/hindcast/09dec14/PointAtkinson.nc')
dec10 = xr.open_dataset('/results/SalishSea/hindcast/10dec14/PointAtkinson.nc')
dec11 = xr.open_dataset('/results/SalishSea/hindcast/11dec14/PointAtkinson.nc')
dec12 = xr.open_dataset('/results/SalishSea/hindcast/12dec14/PointAtkinson.nc')
dec13 = xr.open_dataset('/results/SalishSea/hindcast/13dec14/PointAtkinson.nc')
dec14 = xr.open_dataset('/results/SalishSea/hindcast/14dec14/PointAtkinson.nc')
dec15 = xr.open_dataset('/results/SalishSea/hindcast/15dec14/PointAtkinson.nc')
dec16 = xr.open_dataset('/results/SalishSea/hindcast/16dec14/PointAtkinson.nc')
dec17 = xr.open_dataset('/results/SalishSea/hindcast/17dec14/PointAtkinson.nc')
dec18 = xr.open_dataset('/results/SalishSea/hindcast/18dec14/PointAtkinson.nc')
dec19 = xr.open_dataset('/results/SalishSea/hindcast/19dec14/PointAtkinson.nc')
dec20 = xr.open_dataset('/results/SalishSea/hindcast/20dec14/PointAtkinson.nc')
dec21 = xr.open_dataset('/results/SalishSea/hindcast/21dec14/PointAtkinson.nc')
dec22 = xr.open_dataset('/results/SalishSea/hindcast/22dec14/PointAtkinson.nc')
dec23 = xr.open_dataset('/results/SalishSea/hindcast/23dec14/PointAtkinson.nc')
dec24 = xr.open_dataset('/results/SalishSea/hindcast/24dec14/PointAtkinson.nc')
dec25 = xr.open_dataset('/results/SalishSea/hindcast/25dec14/PointAtkinson.nc')
dec26 = xr.open_dataset('/results/SalishSea/hindcast/26dec14/PointAtkinson.nc')
dec27 = xr.open_dataset('/results/SalishSea/hindcast/27dec14/PointAtkinson.nc')
dec28 = xr.open_dataset('/results/SalishSea/hindcast/28dec14/PointAtkinson.nc')
dec29 = xr.open_dataset('/results/SalishSea/hindcast/29dec14/PointAtkinson.nc')
dec30 = xr.open_dataset('/results/SalishSea/hindcast/30dec14/PointAtkinson.nc')
dec31 = xr.open_dataset('/results/SalishSea/hindcast/31dec14/PointAtkinson.nc')

# %%
nov01
# Out:
# <xarray.Dataset>
# Dimensions:               (axis_nbounds: 2, nvertex: 4, time_counter: 144, x: 1, y: 1)
# Coordinates:
#     nav_lat               (y, x) float32 49.3379
#     nav_lon               (y, x) float32 -123.248
#     time_centered         (time_counter) datetime64[ns] 2014-11-01T00:05:00 ...
#   * time_counter          (time_counter) datetime64[ns] 2014-11-01T00:05:00 ...
# Dimensions without coordinates: axis_nbounds, nvertex, x, y
# Data variables:
#     bounds_lon            (y, x, nvertex) float32 -123.249 -123.243 -123.247 ...
#     bounds_lat            (y, x, nvertex) float32 49.3351 49.3369 49.3408 49.339
#     area                  (y, x) float32 214027.0
#     sossheig              (time_counter, y, x) float64 0.3556 0.2906 0.2277 ...
#     time_centered_bounds  (time_counter, axis_nbounds) float64 3.624e+09 ...
#     time_counter_bounds   (time_counter, axis_nbounds) float64 3.624e+09 ...
# Attributes:
#     name:         PointAtkinson
# ...

# %%
nov01.sossheig.plot(figsize=(60,50))
nov02.sossheig.plot()
nov03.sossheig.plot()
nov04.sossheig.plot()
nov05.sossheig.plot()
nov06.sossheig.plot()
nov07.sossheig.plot()
nov08.sossheig.plot()
nov09.sossheig.plot()
nov10.sossheig.plot()
nov11.sossheig.plot()
nov12.sossheig.plot()
nov13.sossheig.plot()
nov14.sossheig.plot()
nov15.sossheig.plot()
nov16.sossheig.plot()
nov17.sossheig.plot()
nov18.sossheig.plot()
nov19.sossheig.plot()
nov20.sossheig.plot()
nov21.sossheig.plot()
nov22.sossheig.plot()
nov23.sossheig.plot()
nov24.sossheig.plot()
nov25.sossheig.plot()
nov26.sossheig.plot()
nov27.sossheig.plot()
nov28.sossheig.plot()
nov29.sossheig.plot()
nov30.sossheig.plot()
plt.grid('on')

# %%
dec01.sossheig.plot(figsize = (60,50))
dec02.sossheig.plot()
dec03.sossheig.plot()
dec04.sossheig.plot()
dec05.sossheig.plot()
dec06.sossheig.plot()
dec07.sossheig.plot()
dec08.sossheig.plot()
dec09.sossheig.plot()
dec10.sossheig.plot()
dec11.sossheig.plot()
dec12.sossheig.plot()
dec13.sossheig.plot()
dec14.sossheig.plot()
dec15.sossheig.plot()
dec16.sossheig.plot()
dec17.sossheig.plot()
dec18.sossheig.plot()
dec19.sossheig.plot()
dec20.sossheig.plot()
dec21.sossheig.plot()
dec22.sossheig.plot()
dec23.sossheig.plot()
dec24.sossheig.plot()
dec25.sossheig.plot()
dec26.sossheig.plot()
dec27.sossheig.plot()
dec28.sossheig.plot()
dec29.sossheig.plot()
dec30.sossheig.plot()
dec31.sossheig.plot()
plt.grid('on')

# %%
plt.figure(figsize=(20,10))
dec23.sossheig.plot()
dec24.sossheig.plot()
nov09.sossheig.plot()
nov25.sossheig.plot()
plt.grid('on')
