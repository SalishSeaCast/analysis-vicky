# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = nc.Dataset('/home/vdo/Downloads/all_years.nc')

# %%
for n in range(4):
    fig, ax = plt.subplots()
    b =ax.pcolormesh(f.variables['deep_vosaline'][n,...])
    fig.colorbar(b, ax=ax)

# %%
for n in range(4):
    fig, ax = plt.subplots()
    b =ax.pcolormesh(f.variables['deep_votemper'][n,...])
    fig.colorbar(b, ax=ax)

# %%
for n in range(4):
    fig, ax = plt.subplots()
    b =ax.pcolormesh(f.variables['top_vosaline'][n,...])
    fig.colorbar(b, ax=ax)

# %%
for n in range(4):
    fig, ax = plt.subplots()
    b =ax.pcolormesh(f.variables['top_votemper'][n,...])
    fig.colorbar(b, ax=ax)
