# %% [markdown]
# # SalishSeaLake June

# %%
import xarray as xr
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
TN = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_T.nc')
UN = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_U.nc')
VN = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_V.nc')
WN = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_W.nc')

TS = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/JunS0.1/SalishSea_1h_20160601_20160602_grid_T.nc')
US = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/JunS0.1/SalishSea_1h_20160601_20160602_grid_U.nc')
VS = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/JunS0.1/SalishSea_1h_20160601_20160602_grid_V.nc')
WS = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/JunS0.1/SalishSea_1h_20160601_20160602_grid_W.nc')

# %%
figs,(ax1,ax2) = plt.subplots(1,2,sharey = True,figsize = (10,8))
TN.sossheig.isel(time_counter = 0).plot(ax=ax1)
TS.sossheig.isel(time_counter = 0).plot(ax=ax2)

# %%
figs,(ax1,ax2) = plt.subplots(1,2,sharey = True,figsize = (10,8))
TN.sossheig.isel(time_counter = 23).plot(ax=ax1)
TS.sossheig.isel(time_counter = 23).plot(ax=ax2)

# %%
figs,(ax1,ax2) = plt.subplots(1,2,sharey = True,figsize = (10,8))
VN.vomecrty.isel(depthv = 0,time_counter = 23).plot(ax = ax1)
VS.vomecrty.isel(depthv = 0,time_counter = 23).plot(ax = ax2)

# %%
figs,(ax1,ax2) = plt.subplots(1,2,sharey = True,figsize=(20,8))
VN.vomecrty.isel(y=150,time_counter=23).plot(ax=ax1)
VS.vomecrty.isel(y=150,time_counter=23).plot(ax=ax2)
ax1.set_ylim((50,0))
ax2.set_ylim((50,0))
# Out:
# (50, 0)
