# %%
import netCDF4 as nc
import numpy as np 
import matplotlib.pyplot as plt
import datetime as dt
import cmocean
import datetime
from salishsea_tools import nc_tools, viz_tools
# %matplotlib inline

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.titlesize'] = 18

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
f2015top = nc.Dataset('/data/vdo/MEOPAR/sum_dfc/seasonal-30_2015.nc')
f2016top = nc.Dataset('/data/vdo/MEOPAR/sum_dfc/seasonal-30_2016.nc')
f2017top = nc.Dataset('/data/vdo/MEOPAR/sum_dfc/seasonal-30_2017.nc')

# %%
t_averages = (f2015top.variables['sum_dfc'][:] 
              + f2016top.variables['sum_dfc'][:]
              + f2017top.variables['sum_dfc'][:])/3

# %%
mesh = nc.Dataset('/data/vdo/MEOPAR/NEMO-forcing/grid/mesh_mask201702.nc')

# %%
for n in range(4):
    i = np.ma.masked_array(t_averages[n,...],
                                           mask = 1 - mesh.variables['tmask'][0,22,...])
    print(i.min(), i.max())
# Out:
# 3e-08 0.7865378
# 3e-08 4.59374
# 3e-08 5.159561
# 3e-08 2.2011611

# %%
fig, axs = plt.subplots(1,4,figsize = (30,10))
s = axs[0].pcolormesh(np.ma.masked_array(t_averages[0,...],
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.matter, vmin = 0, vmax = 5)
fig.colorbar(s, ax=axs[0])
viz_tools.set_aspect(axs[0])
axs[0].set_title('Winter Averaged Diatoms+Flagellates+Ciliates')

s = axs[1].pcolormesh(np.ma.masked_array(t_averages[1,...],
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.matter, vmin = 0, vmax = 5)
fig.colorbar(s, ax=axs[1])
viz_tools.set_aspect(axs[1])
axs[1].set_title('Spring Averaged Diatoms+Flagellates+Ciliates')

s = axs[2].pcolormesh(np.ma.masked_array(t_averages[2,...],
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.matter, vmin = 0, vmax = 5)
fig.colorbar(s, ax=axs[2])
viz_tools.set_aspect(axs[2])
axs[2].set_title('Summer Averaged Diatoms+Flagellates+Ciliates')

s = axs[3].pcolormesh(np.ma.masked_array(t_averages[3,...],
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.matter, vmin = 0, vmax = 5)
fig.colorbar(s, ax=axs[3])
viz_tools.set_aspect(axs[3])
axs[3].set_title('Fall Averaged Diatoms+Flagellates+Ciliates');

# %%
fig, axs = plt.subplots(1,4,figsize = (30,10))

s = axs[0].pcolormesh(np.ma.masked_array(f2015top.variables['sum_dfc'][0,...] 
                                           - t_averages[0,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[0])
viz_tools.set_aspect(axs[0])
axs[0].set_title('Winter, 2015 - averaged Diatoms+Flagellates+Ciliates')

s = axs[1].pcolormesh(np.ma.masked_array(f2015top.variables['sum_dfc'][1,...] 
                                           - t_averages[1,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[1])
viz_tools.set_aspect(axs[1])
axs[1].set_title('Spring, 2015 - averaged')

s = axs[2].pcolormesh(np.ma.masked_array(f2015top.variables['sum_dfc'][2,...] 
                                           - t_averages[2,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[2])
viz_tools.set_aspect(axs[2])
axs[2].set_title('Summer, 2015 - averaged')

s = axs[3].pcolormesh(np.ma.masked_array(f2015top.variables['sum_dfc'][3,...] 
                                           - t_averages[3,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[3])
viz_tools.set_aspect(axs[3])
axs[3].set_title('Fall, 2015 - averaged Diatoms+Flagellates+Ciliates');

# %%
fig, axs = plt.subplots(1,4,figsize = (30,10))

s = axs[0].pcolormesh(np.ma.masked_array(f2016top.variables['sum_dfc'][0,...] 
                                           - t_averages[0,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[0])
viz_tools.set_aspect(axs[0])
axs[0].set_title('Winter, 2016 - averaged Diatoms+Flagellates+Ciliates')

s = axs[1].pcolormesh(np.ma.masked_array(f2016top.variables['sum_dfc'][1,...] 
                                           - t_averages[1,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[1])
viz_tools.set_aspect(axs[1])
axs[1].set_title('Spring, 2016 - averaged')

s = axs[2].pcolormesh(np.ma.masked_array(f2016top.variables['sum_dfc'][2,...] 
                                           - t_averages[2,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[2])
viz_tools.set_aspect(axs[2])
axs[2].set_title('Summer, 2016 - averaged')

s = axs[3].pcolormesh(np.ma.masked_array(f2016top.variables['sum_dfc'][3,...] 
                                           - t_averages[3,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[3])
viz_tools.set_aspect(axs[3])
axs[3].set_title('Fall, 2016 - averaged Diatoms+Flagellates+Ciliates');

# %%
fig, axs = plt.subplots(1,4,figsize = (30,10))

s = axs[0].pcolormesh(np.ma.masked_array(f2017top.variables['sum_dfc'][0,...] 
                                           - t_averages[0,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[0])
viz_tools.set_aspect(axs[0])
axs[0].set_title('Winter, 2017 - averaged Diatoms+Flagellates+Ciliates')

s = axs[1].pcolormesh(np.ma.masked_array(f2017top.variables['sum_dfc'][1,...] 
                                           - t_averages[1,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[1])
viz_tools.set_aspect(axs[1])
axs[1].set_title('Spring, 2017 - averaged')

s = axs[2].pcolormesh(np.ma.masked_array(f2017top.variables['sum_dfc'][2,...] 
                                           - t_averages[2,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[2])
viz_tools.set_aspect(axs[2])
axs[2].set_title('Summer, 2017 - averaged')

s = axs[3].pcolormesh(np.ma.masked_array(f2017top.variables['sum_dfc'][3,...] 
                                           - t_averages[3,...], 
                                           mask = 1 - mesh.variables['tmask'][0,22,...]), 
                        cmap = cmocean.cm.balance, vmin = -1, vmax = 1)
fig.colorbar(s, ax=axs[3])
viz_tools.set_aspect(axs[3])
axs[3].set_title('Fall, 2017 - averaged Diatoms+Flagellates+Ciliates');

# %%
n = nc.Dataset('/data/vdo/MEOPAR/sum_dfc/all_years_averages.nc', 'w')

# %%
time = n.createDimension("time_counter", None)
y = n.createDimension("y", 898)
x = n.createDimension("x", 398)

# %%
times = n.createVariable("time","f8",("time_counter",))
top_T = n.createVariable("sum_dfc","f4",("time_counter","y", "x"))

# %%
dates = [datetime.datetime(2016, 1, 15, 12, 0), datetime.datetime(2016, 4, 16, 0, 0),
         datetime.datetime(2016, 7, 17, 0, 0), datetime.datetime(2016, 10, 16, 12, 0)]

# %%
f2015top.variables['time_counter'].units
# Out:
# 'seconds since 1900-01-01 00:00:00'

# %%
times[:] = nc.date2num(dates,'seconds since 1900-01-01 00:00:00')

# %%
top_T[:] = t_averages

# %%
n.close()
