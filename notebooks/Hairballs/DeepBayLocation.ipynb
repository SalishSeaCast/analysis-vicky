# %%
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline
from salishsea_tools import viz_tools

# %%
grid = xr.open_dataset('/data/vdo/MEOPAR/NEMO-forcing/grid/bathymetry_201702.nc')

# %%
fig,ax = plt.subplots(1,1,figsize=(20,16))
grid.Bathymetry.plot()
viz_tools.set_aspect(ax)
ax.plot(155,558,'r*',markersize=10)
ax.plot(125,599,'y*', markersize=10)
plt.savefig('Locations.png', bbox_inches='tight')
