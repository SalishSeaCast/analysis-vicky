# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from salishsea_tools import (nc_tools, viz_tools, gsw_calls)
import numpy.ma as ma
from matplotlib import animation, rc
import glob
import xarray as xr
import scipy.signal as signal
# %matplotlib inline

# %%
rc('animation', html='html5')

# %%
a = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/apr15_notrc/output.abort.nc')
b = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/dec15_notrc/output.abort.nc')
c = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/nov15_notrc/output.abort.nc')
d = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/may16_notrc/output.abort.nc')

# %%
mesh_mask = nc.Dataset('/data/vdo/MEOPAR/NEMO-forcing/grid/mesh_mask201702.nc')

# %%
for file in [a,b,c,d]:
    fig, ax = plt.subplots(figsize = (12,10))
    ax.pcolormesh(mesh.variables['tmask'][0,0,...])
    for j, i in np.argwhere(np.isnan(file.variables['vosaline'][0,0,...])):
        if (mesh.variables['tmask'][0,0,j,i]) == 1:
            ax.plot(i, j, 'r.')
    ax.set_title(nc.num2date(file.variables['time_counter'][0], 
                             file.variables['time_counter'].units))
    viz_tools.set_aspect(ax)

# %%
plt.pcolormesh(np.ma.masked_array(a.variables['votemper'][0,:,896, 44:57],
                                 mask = 1-mesh_mask.variables['tmask'][0,:, 896, 44:57]))
plt.colorbar()

# %%
plt.pcolormesh(np.ma.masked_array(a.variables['vosaline'][0,:,896, 30:60],
                                 mask = 1-mesh_mask.variables['tmask'][0,:, 896, 30:60]))
plt.colorbar()

# %%
den = gsw_calls.generic_gsw_caller('gsw_rho.m', [a.variables['vosaline'][0,:,896, 44:57], 
                                                a.variables['votemper'][0,:,896, 44:57],
                                                depths])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-3702cd084f65> in <module>()
#       1 den = gsw_calls.generic_gsw_caller('gsw_rho.m', [a.variables['vosaline'][0,:,896, 44:57],
#       2                                                 a.variables['votemper'][0,:,896, 44:57],
# ----> 3                                                 depths.T])
#
# /data/vdo/MEOPAR/tools/SalishSeaTools/salishsea_tools/gsw_calls.py in generic_gsw_caller(gsw_function_name, input_vars, matlab_gsw_dir)
#      57     _run_matlab(functioncall)
#      58     # load output from matlab
# ---> 59     output_data = np.loadtxt(output, delimiter=',')
#      60     # remove tmp files
#      61     for f in tmp_files:
#
# /home/vdo/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
# ...

# %%
a.variables['vosaline'][0,:,896, 44:57].shape
# Out:
# (40, 13)

# %%
a.variables['deptht'][:].shape
# Out:
# (40,)

# %%
fig, ax = plt.subplots(figsize = (12,8))
ax.pcolormesh(a.variables['vosaline'][0,0,550:800, 115:250])
ax.plot([0,75],[90,90], 'r-')
ax.plot([0,80],[150,150], 'r-')
ax.plot([30,30],[0,250], 'r-')
viz_tools.set_aspect(ax)
# Out:
# 1.1363636363636362

# %%
import datetime

# %%
306721+(2160*10)*9
# Out:
# 501121

# %%
datetime.date(2015,2,21) + datetime.timedelta(days = 10)
# Out:
# datetime.date(2015, 3, 3)

# %%
import pandas as pd

# %%
f = nc.Dataset('/data/vdo/MEOPAR/SalishSea/sixtracerstest/SalishSea_1h_20160430_20160430_ptrc_T.nc')

# %%
f = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/jul17_notrc/output.abort.nc')

# %%
plt.pcolormesh(np.ma.masked_array(f.variables['vozocrtx'][0,0,...],
                                 mask = 1-mesh_mask.variables['umask'][0,0,...]),
                                 vmin = -5, vmax = 5)
plt.plot(144, 71, 'ro')
plt.colorbar()
plt.ylim(40,80)
plt.xlim(130,160)
# Out:
# (130, 160)

# %%
plt.pcolormesh(mesh_mask.variables['tmask'][0,0,...], cmap = 'binary')
plt.plot(67,889, 'ro', label = 'apr15_notrc')
plt.plot(23, 428, 'go', label = 'dec15_notrc')
plt.plot(144,71, 'yo', label = 'jul17_notrc')
plt.plot(144,72, 'bo', label = 'jul17_notrc1')
plt.legend()

# %%
a = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/jul17_notrc2/output.abort.nc')
b = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/jul17_notrc3/output.abort.nc')
c = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/jun16_notrc/output.abort.nc')
d = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/jun16_notrc2/output.abort.nc')
e = nc.Dataset('/ocean/vdo/MEOPAR/failed-runs/jun17_notrc/output.abort.nc')

# %%
for file in [a,b,c,d,e]:
    fig, ax = plt.subplots(figsize = (12,10))
    ax.pcolormesh(mesh_mask.variables['tmask'][0,0,...])
    for j, i in np.argwhere(np.isnan(file.variables['vosaline'][0,0,...])):
        if (mesh_mask.variables['tmask'][0,0,j,i]) == 1:
            ax.plot(i, j, 'r.')
    ax.set_title(nc.num2date(file.variables['time_counter'][0], 
                             file.variables['time_counter'].units))
    viz_tools.set_aspect(ax)

# %%
datetime.date(2017, 2, 10).strftime("%d%b%y").lower()
# Out:
# '10feb17'
