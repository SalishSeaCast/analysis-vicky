# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
import scipy.io as sio
import pandas as pd
import datetime
import xarray as xr
from salishsea_tools import tidetools, geo_tools, viz_tools
from matplotlib.colors import LinearSegmentedColormap
import os
import h5py
# %matplotlib inline

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
f = nc.Dataset('/ocean/vdo/MIDOSS/Lagrangian_AKNS_crude_test_vvl.nc')

# %% [markdown]
# ## surface

# %%
for n in np.arange(1,21):
    fig, ax = plt.subplots()
    ax.set_title('h = ' +str(n))
    mesh = ax.pcolormesh(f['OilConcentration_3D'][n,39,300:400, 200:350], 
                         cmap = 'Blues_r', vmin = 0, vmax = 0.5)
    fig.colorbar(mesh, ax=ax)

# %% [markdown]
# ## sum of depth !=0

# %%
for n in np.arange(1,21):
    fig, ax = plt.subplots()
    ax.set_title('h = ' +str(n))
    mesh = ax.pcolormesh(np.sum(f['OilConcentration_3D'][n,:39,300:400, 200:350], axis = 0), 
                  cmap = 'Blues_r', vmin = 0, vmax = 0.3)
    fig.colorbar(mesh, ax=ax)
