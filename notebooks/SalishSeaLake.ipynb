# %% [markdown]
# ## Salish Sea Lake
# ### May 12, 2017

# %%
import xarray as xr
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
T = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJan/SalishSea_1h_20170101_20170101_grid_T.nc')
U = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJan/SalishSea_1h_20170101_20170101_grid_U.nc')
V = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJan/SalishSea_1h_20170101_20170101_grid_V.nc')
T2 = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_T.nc')
U2 = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_U.nc')
V2 = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_V.nc')

# %%
figs,axs = plt.subplot(1,2,sharey=True)

T.sossheig.isel(time_counter = 23).plot()

# %%
fig,ax = plt.subplots(1,1)
T.votemper.isel(y=150,time_counter=23).plot(ax=ax)
ax.set_ylim((50,0))
ax.set_xlim((75,245))
# Out:
# (75, 245)

# %%
V.vomecrty.isel(depthv = 0,time_counter = 23).plot()

# %%
fig,ax = plt.subplots(1,1)
V.vomecrty.isel(y=150,time_counter=23).plot(ax=ax)
ax.set_ylim((50,0))
# Out:
# (50, 0)
