# %% [markdown]
# ## Salish Sea Lake
# ### May 12, 2017

# %%
import xarray as xr
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
T = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_T.nc')
U = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_U.nc')
V = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_V.nc')
W = xr.open_dataset('/data/vdo/MEOPAR/completed-runs/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_W.nc')

# %%
T.sossheig.isel(time_counter=23).plot()

# %%
fig,ax = plt.subplots(1,1)

T.vosaline.isel(time_counter=23, y = 175).plot(ax=ax,levels=range(20,30))
ax.set_ylim((0,50))
ax.set_xlim((75,180))
ax.invert_yaxis()

# %%
T.sossheig.isel(time_counter=0).plot()

# %%
T.vosaline.isel(time_counter=0,deptht=0).plot()

# %%
398-114
# Out:
# 284

# %%
V
# Out:
# <xarray.Dataset>
# Dimensions:               (axis_nbounds: 2, depthv: 40, nvertex: 4, time_counter: 24, x: 204, y: 564)
# Coordinates:
#   * depthv                (depthv) float32 0.5 1.5 2.50001 3.50003 4.50007 ...
#     nav_lat               (y, x) float32 48.3961 48.398 48.4 48.4019 48.4038 ...
#     nav_lon               (y, x) float32 -123.92 -123.914 -123.909 -123.904 ...
#     time_centered         (time_counter) datetime64[ns] 2016-06-01T00:30:00 ...
#   * time_counter          (time_counter) datetime64[ns] 2016-06-01T00:30:00 ...
# Dimensions without coordinates: axis_nbounds, nvertex, x, y
# Data variables:
#     area                  (y, x) float32 222164.0 222145.0 222127.0 222108.0 ...
#     bounds_lat            (y, x, nvertex) float32 48.3961 48.3961 48.3961 ...
#     bounds_lon            (y, x, nvertex) float32 -123.92 -123.92 -123.92 ...
#     depthv_bounds         (depthv, axis_nbounds) float32 0.0 1.0 1.0 2.00001 ...
# ...

# %%
W
# Out:
# <xarray.Dataset>
# Dimensions:               (axis_nbounds: 2, depthw: 40, nvertex: 4, time_counter: 24, x: 204, y: 564)
# Coordinates:
#   * depthw                (depthw) float32 0.0 1.0 2.00001 3.00002 4.00005 ...
#     nav_lat               (y, x) float32 48.3941 48.396 48.398 48.3999 ...
#     nav_lon               (y, x) float32 -123.918 -123.913 -123.908 -123.902 ...
#     time_centered         (time_counter) datetime64[ns] 2016-06-01T00:30:00 ...
#   * time_counter          (time_counter) datetime64[ns] 2016-06-01T00:30:00 ...
# Dimensions without coordinates: axis_nbounds, nvertex, x, y
# Data variables:
#     area                  (y, x) float32 222177.0 222158.0 222140.0 222121.0 ...
#     bounds_lat            (y, x, nvertex) float32 48.3941 48.3941 48.3941 ...
#     bounds_lon            (y, x, nvertex) float32 -123.918 -123.918 -123.918 ...
#     depthw_bounds         (depthw, axis_nbounds) float32 -0.5 0.5 0.5 1.5 ...
# ...

# %%
T = xr.open_dataset('/home/vdo/MEOPAR/SalishSea/SalishSeaLakeJun/SalishSea_1h_20160601_20160601_grid_T.nc')

# %%
T.vosaline.isel(deptht=0,time_counter=10).values
# Out:
# array([[  0.,   0.,   0., ...,   0.,   0.,   0.],
#        [  0.,  nan,  nan, ...,  nan,  nan,   0.],
#        [  0.,  nan,  nan, ...,  nan,  nan,   0.],
#        ...,
#        [  0.,  nan,  nan, ...,  nan,  nan,   0.],
#        [  0.,  nan,  nan, ...,  nan,  nan,   0.],
#        [  0.,   0.,   0., ...,   0.,   0.,   0.]])
